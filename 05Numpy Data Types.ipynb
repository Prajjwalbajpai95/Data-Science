# %%
import numpy as np

# %%
arr = np.array([23,45,65,34])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype("float64")
# Out:
# array([23., 45., 65., 34.])

# %%
arr2 = np.array([2,4,6,3], dtype="float32")

# %%
arr2
# Out:
# array([2., 4., 6., 3.], dtype=float32)

# %%
arr.nbytes
# Out:
# 32

# %%
arr2.nbytes
# Out:
# 16

# %%
arr3 = np.array([1 + 2j, 3 + 4j, 5 + 6j], dtype = 'complex128')
print(arr3)
# Out:
# [1.+2.j 3.+4.j 5.+6.j]

# %%
arr4 = np.array([{'a': 1},[1,2,3], 'hello'], dtype = object)
print(arr4)
# Out:
# [{'a': 1} list([1, 2, 3]) 'hello']

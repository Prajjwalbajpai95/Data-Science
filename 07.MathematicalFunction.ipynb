# %%
import numpy as np

# %%
arr = np.array([3,4,6,5])

# %%
np.mean(arr)
# Out:
# np.float64(4.5)

# %%
np.max(arr)
# Out:
# np.int64(6)

# %%
np.min(arr)
# Out:
# np.int64(3)

# %%
np.std(arr)
# Out:
# np.float64(1.118033988749895)

# %%
np.var(arr)
# Out:
# np.float64(1.25)

# %%
np.percentile(arr,10)
# Out:
# np.float64(3.3)

# %%
np.argmin(arr)
# Out:
# np.int64(0)

# %%
np.cumsum(arr)
# Out:
# array([ 3,  7, 13, 18])
